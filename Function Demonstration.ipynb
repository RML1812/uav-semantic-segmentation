# %% [markdown]
# ## Import

# %%
from functions import *

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Function Usage

# %%
image, mask = get_image_and_mask()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(image)
axarr[1].imshow(mask)

# %%
features = extract_features(image)

# %%
result = kmeans_manual(image, features, 5, 50)
plt.imshow(result)

# %%
size, score, result = kmeans_auto(image, mask, features, 50)
plt.imshow(result)

# %%
print(f"Cluster = {size}, Score = {score}")
# Out:
# Cluster = 4, Score = 0.5923613181270533
